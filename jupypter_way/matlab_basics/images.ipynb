# %% [markdown]
# <h1>Image Processing</h1>
# <h2>Basics of Digital World</h2>
# <li>Most of the digital world operates on <b>8 bit images</b></li>
# <li>This includes your inkjet printer and usually your monitor</li>
# <li>What this means is that <font color="blue">8 bits of information</font> are used to <font color="blue">create the image that you usually see</font></li>
#
# Reference: https://matplotlib.org/users/image_tutorial.html
#
# * Loading image data is supported by the Pillow library
# * Natively, matplotlib only supports PNG images
#
# <h2>Example</h2>
# <li><font color="red">Upload the image file in notebook server</font></li>
# <li>Run the following program</li>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %matplotlib inline

img=mpimg.imread('stinkbug.png')
imgplot = plt.imshow(img)
